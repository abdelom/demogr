# %% [markdown]
# <div style="color:#8b1538; font-size:32px;">Graphic representation using matplotlib and seaborn</div>

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# <br>

# %% [markdown]
# # SNPs distribution

# %% [markdown]
# > Load data

# %%
def load_data(model):
    # Path data
    path_data = "../../Data/Msprime/snp_distribution/sfs_{}/".format(model)
    
    data = pd.read_json(path_or_buf="{}SFS_{}-all.json".format(path_data, model), typ='frame')
    
    return data

# %%
sfs_decline = load_data("decline")

# %%
sfs_decline
# Out:
#                                              Parameters              SNPs  \
# 0     {'Tau': 0.015848931900000002, 'Kappa': 0.10471...    [13833, 14330]
# 1     {'Tau': 0.0003981072, 'Kappa': 0.4570881896, '...    [52199, 51984]
# 2     {'Tau': 794.3282347243, 'Kappa': 38.0189396321...  [112995, 114286]
# 3     {'Tau': 251.188643151, 'Kappa': 0.1047128548, ...  [114197, 112770]
# 4     {'Tau': 125.8925411794, 'Kappa': 21.8776162395...  [113312, 114235]
# ...                                                 ...               ...
# 5370  {'Tau': 15.8489319246, 'Kappa': 0.0066069345, ...  [113162, 112199]
# 5371  {'Tau': 63.095734448, 'Kappa': 0.0239883292000...  [112568, 112101]
# 5372  {'Tau': 1584.8931924611, 'Kappa': 79.432823472...  [113319, 113292]
# 5373  {'Tau': 0.0006309573, 'Kappa': 0.034673685, 's...      [4005, 4011]
# 5374  {'Tau': 0.0125892541, 'Kappa': 7.2443596007, '...  [817168, 807377]
#
#                                            SFS observed       Time
# ...

# %% [markdown]
# <br>

# %%
# Compute log10 of kappa & tau
sfs_decline['Log10(Tau)'] = sfs_decline['Parameters'].apply(lambda ele: np.log10(ele['Tau']))
sfs_decline['Log10(Kappa)'] = sfs_decline['Parameters'].apply(lambda ele: np.log10(ele['Kappa']))

# Compute mean of SNPs (then log10)
sfs_decline['SNPs'] = sfs_decline['SNPs'].apply(lambda ele: np.mean(ele))
somme = sum(sfs_decline['SNPs'])
sfs_decline['SNPs'] = sfs_decline['SNPs'].apply(lambda ele: ele/somme)

# %%
sfs_bis = sfs_decline[['Log10(Tau)', 'Log10(Kappa)', 'SNPs']]
sfs_bis
# Out:
#       Log10(Tau)  Log10(Kappa)      SNPs
# 0           -1.8         -0.98  0.000016
# 1           -3.4         -0.34  0.000058
# 2            2.9          1.58  0.000126
# 3            2.4         -0.98  0.000126
# 4            2.1          1.34  0.000126
# ...          ...           ...       ...
# 5370         1.2         -2.18  0.000125
# 5371         1.8         -1.62  0.000125
# 5372         3.2          1.90  0.000126
# 5373        -3.2         -1.46  0.000004
# 5374        -1.9          0.86  0.000902
#
# [5375 rows x 3 columns]

# %%
sfs_bis = sfs_bis.groupby(['Log10(Tau)', 'Log10(Kappa)']).mean().unstack('Log10(Kappa)')
sfs_bis
# Out:
#                       SNPs                                            \
# Log10(Kappa)         -3.30         -3.22         -3.14         -3.06
# Log10(Tau)
# -4.0          7.107784e-08  9.828732e-08  9.106848e-08  1.310498e-07
# -3.9          8.884730e-08  9.273436e-08  9.328966e-08  1.149462e-07
# -3.8          8.329434e-08  1.099485e-07  1.105038e-07  1.327156e-07
# -3.7          9.106848e-08  1.177227e-07  1.299392e-07  1.543722e-07
# -3.6          8.773670e-08  1.304945e-07  1.410451e-07  1.804711e-07
# ...                    ...           ...           ...           ...
#  3.5          1.257978e-04  1.255340e-04  1.259738e-04  1.258750e-04
#  3.6          1.260110e-04  1.256273e-04  1.251186e-04  1.263075e-04
#  3.7          1.261831e-04  1.267462e-04  1.269261e-04  1.260726e-04
#  3.8          1.263681e-04  1.265019e-04  1.259566e-04  1.272954e-04
#  3.9          1.258494e-04  1.255890e-04  1.247094e-04  1.263592e-04
#
# ...

# %% [markdown]
# > Plot data

# %%
def snp_distribution_3d(data):
    # Plot
    sns.set_theme(style='whitegrid')

    # Plot
    sns.heatmap(data)
        
    plt.show()

# %%
# %matplotlib widget
snp_distribution_3d(sfs_bis)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
